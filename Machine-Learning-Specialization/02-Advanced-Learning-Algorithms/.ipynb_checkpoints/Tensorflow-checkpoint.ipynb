# %% [markdown]
# import numpy as np

# %% [raw]
# layer_1 = Dense(units=3, activation="sigmoid")
# layer_2 = Dense(units=1, activation="sigmoid")
# model = Sequantial([layer_1, layer_2])
#
# x = np.array([[200.0, 17.0],
#              [120.0, 5.0],
#              [425.0, 20.0],
#              [212.0, 18.0]])
#
# y = np.array([1,0,0,1])
# model.compile(...)
# model.fit(x,y)
# model.predict(x_new)

# %% [raw]
# model = Sequantial([
#     Dense(units=3, activation="sigmoid"),
#     Dense(units=1, activation="sigmoid")])
#
# x = np.array([[200.0, 17.0],
#              [120.0, 5.0],
#              [425.0, 20.0],
#              [212.0, 18.0]])
#
# y = np.array([1,0,0,1])
# model.compile(...)
# model.fit(x,y)
# model.predict(x_new)

# %% [markdown]
# Digit classification model

# %% [raw]
# layer_1 = Dense(units=25, activation="sigmoid")
# layer_2 = Dense(units=15, activation="sigmoid")
# layer_3 = Dense(units=1, activation="sigmoid")
#
# model = Sequantial([layer_1, layer_2, layer_3])
# model.compile(...)
#
# x = np.array([[0..., 245, ..., 17],
#              [0..., 200, ..., 184]])
#
# model.fit(x,y)
# model.predict(x_new)

# %% [markdown]
# ![image.png](attachment:f9a6d98e-d4bc-4f7b-9c20-ab0566e5116d.png)
